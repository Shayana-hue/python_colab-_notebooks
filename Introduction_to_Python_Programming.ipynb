# %% [markdown]
# <a href="https://colab.research.google.com/github/Shayana-hue/python_colab-_notebooks/blob/python_colab_notebooks/Introduction_to_Python_Programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Session Flow:**
#
# 👨🏻‍🎓 Learning Objective:
#
# * Introduction
# * Theme
# * Primary Goals
#
# 🐍 Introduction to Python and IDE
#
# * Introduction to Python and its key features.
# * Overview of Integrated Development Environments (IDEs) and their significance in Python development.
# * Getting started with Google Colab as a cloud-based IDE for Python. 🌩️
#
# 🖥️ Navigating the IDE and Writing Code
#
# * Tour of the Google Colab interface.
# * Creating and managing notebooks in Colab.
# * Writing your first Python code in Colab.
#
# 📝 Editing and Running Code
#
# * Understanding code cells and text cells in Colab.
# * Editing and modifying Python code within Colab notebooks.
# * Executing code cells to see the output. ▶️
#
#
# 🔢 Basic Data Types in Python
#
# * Overview of fundamental data types in Python: integers, floating-point numbers, strings, booleans.
# * Examples and demonstrations of each data type in Colab.
#
# 💡 Variables and Naming Conventions
#
# * Understanding variables and their role in storing data.
# * Rules for naming variables in Python.
# * Practicing variable declaration and assignment in Colab.
# * Activity 2
#
# 📝 Summary
#
# * Best Practices & Tips
#
# 🔗 Enhance your Knowledge
#
# * Additional Resources
#
# 🔍 Try it Yourself
#
# * Activities

# %% [markdown]
# ## **👨🏻‍🎓 Learning Objective 👨🏻‍🎓**

# %% [markdown]
# ### **Introduction:**
#
# 🐍💻📊
#
# Welcome to the world of Python programming, where you can do amazing things with just a few lines of code! 🎉
#
# Python is a programming language used to create software and programs, and it's especially popular in the field of data science. With Python, you can analyze data, create graphs and charts, and even build simple machine learning models to predict outcomes. 📈🧮
#
# Whether you're working with customer data, financial data, or any other kind of data, Python has the tools you need to make sense of it all. And the best part,  Python is easy to learn and use, making it perfect for beginners who want to dive into the world of programming, making it the ideal choice for your Data Science journey. 🤩
#
# So, get ready to explore the endless possibilities of Python programming for data science! We'll guide you through the basics and show you how to get started. 🤓
#
# * Focus: Python Google Colab, Basic Data Types, Variable Naming
#
# * Pre-requisites: None
#
# ### **Theme:**
#
# Welcome to "Python: Your Gateway to a Connected World"! 🌐🐍 In this hands-on session, we invite you to discover the real-life applications and the immense potential of Python programming in today's interconnected world. From automation to data analysis and web development, Python is the key that unlocks countless opportunities in various domains. 🚀💻
#
#
# ### **Primary Goals:**
#
# 1. Understanding the basic syntax and structure of the Python programming language.
# 2. Getting familiar with the basic concepts and usage of an integrated development environment (IDE), including how to navigate the interface, write and edit code, and run and debug programs.
# 3. Being able to use Google Colab as a cloud-based development environment for Python.
# 4. Getting to know basic data types.
# 5. Understanding variables and certain rules when it comes to naming the variable.

# %% [markdown]
# ## **📖 Learning Material 📖**

# %% [markdown]
# ## Navigating the Data Landscape

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Welcome to the exciting world of data science! In this foundational course, we're embarking on a journey to demystify the diverse and dynamic data landscape.
#
# As you embark on this journey, you might be wondering, "What exactly can I do in this field? What are the different roles, and how do they contribute to the ever-evolving data ecosystem?" These are important questions, especially for those who are new to the field.
#
# But, before we dive in, let's address some common misconceptions. Data science is not a monolithic profession; it's a mosaic of specializations. There's a place for a wide array of skills, from those who love to delve into data analysis and visualization to those who revel in the complexities of machine learning, big data, and artificial intelligence.

# %% [markdown]
# # **The World of Data: Descriptive, Diagnostic, Predictive, and Prescriptive Analytics**
# In the realm of data science, four key types of analytics shape how we understand and act on data:
#
# 1. **Descriptive Analytics**
#
# **What happened?**
# Descriptive analytics focuses on summarizing historical data to understand changes over time. It answers questions like, "What were last quarter’s sales?" or "How many users visited our website?"
#
# 2. **Diagnostic Analytics**
#
# **Why did it happen?**
# This type dives deeper to uncover the causes behind trends or anomalies. It often involves drilling down into data, correlation analysis, and data mining to explain outcomes.
#
# 3. **Predictive Analytics**
#
# **What is likely to happen?**
# Predictive analytics uses historical data, statistical algorithms, and machine learning techniques to forecast future events. For example, it might predict customer churn or future sales trends.
#
# 4. **Prescriptive Analytics**
#
# **What should we do about it?**
# The most advanced type, prescriptive analytics, suggests actions to take based on predicted outcomes. It uses optimization, simulation, and decision modeling to guide strategic decisions.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Data-related roles can be grouped into broader categories based on their primary functions and areas of expertise. Here's a grouping of data roles:**

# %% [markdown]
# **Data Analysis and Reporting:**
#
# * **Data Analyst**: Examines and interprets data to help organizations make informed decisions.
# * **Business Intelligence Analyst**: Focuses on transforming data into actionable insights to drive business strategies.
# * **Market Research Analyst**: Collects and analyzes data to provide insights into market trends and consumer behavior.
# * **Healthcare Data Analyst**: Specializes in analyzing healthcare data to improve patient care and operational efficiency.
#
# and more..
#
# **Data Science and Machine Learning:**
#
# * **Data Scientist**: Develops models and algorithms to extract insights and knowledge from data.
# * **Machine Learning Engineer**: Designs and builds machine learning systems and models for predictive analytics.
# * **AI Engineer**: Develops artificial intelligence systems and applications using machine learning and deep learning techniques.
# * **Statistician**: Applies statistical methods to analyze data and draw meaningful conclusions.
#
# and more..

# %% [markdown]
# ####**What makes Netflix Chill? 😉**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Netflix's personalized streaming experience is powered by a team of data professionals working behind the scenes:
#
# **Data Analysts:** They analyze your past viewing history using descriptive analytics, identifying your favorite genres, actors, and directors. Their work provides the foundation for understanding what you've previously enjoyed and sets the stage for personalized recommendations.
#
# **Data Scientists:** Leveraging insights from data analysts, data scientists use predictive analytics to build models that forecast what you’re likely to watch next. Their work enables real-time personalized suggestions, keeping you engaged with content you're most likely to enjoy.
#
# **Data Engineers:** Data engineers create and maintain the infrastructure that processes and delivers massive amounts of data efficiently.
#
# These data roles work together to create a tailored Netflix experience, ensuring that every recommendation, show, and category is personalized just for you.

# %% [markdown]
# Armed with this understanding, let's proceed and delve into the tool that is undeniably pivotal as you continue on your journey- **Python**

# %% [markdown]
# #### **Preparing the Data Arsenal**

# %% [markdown]
# Going forward you will be introduced to an array of tools that will make you preapred to tackle the world of data. Let's have a look at them

# %% [markdown]
# 1. **Python**:
#
# Used for: Writing code to analyze, manipulate, and visualize data, as well as building machine learning models for predictions and automation.
#
# 2. **SQL (Structured Query Language)**:
#
# Used for: Querying and managing large datasets in databases, enabling data retrieval, filtering, and aggregation for analysis and reporting.
#
# 3. **Excel**:
#
# Used for: Organizing, calculating, and conducting basic data analysis, making it a valuable tool for small-scale data management and visualization.
#
# 4. **Business Intelligence (BI) Tools**:
#
# Used for: Creating interactive, user-friendly dashboards and reports that help businesses and organizations make informed decisions based on data insights.
#
# 4. **Statistics**:
#
# Used for: Employing mathematical techniques to summarize, interpret, and draw conclusions from data, allowing for a deeper understanding of underlying trends and patterns.
#
# 5. **Machine Learning (ML) and Related Libraries**:
#
# Used for: Developing and applying algorithms that enable computers to learn from data, recognize patterns, and make predictions or automated decisions, with applications ranging from image recognition to recommendation systems.
#
#
# Keep in mind that this is not an exhaustive list. The field of data is ever evolving and advancements pops every now and then. Always be ready to adapt to this ever changind landscape.

# %% [markdown]
# ####**Your Journey to Become a DA/DS**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now let's get going and take the very first step in this journey!! All the best!

# %% [markdown]
# ### Introduction to Python Programming

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Hello students!
#
# Today, we will begin our journey into Python programming, which is one of the most popular programming languages in the field of data science. Python is known for its versatility and power, making it a suitable choice for various data science tasks, such as data cleaning, preprocessing, analysis, and modeling. Learning Python will provide you with access to a wide range of libraries and tools that are specifically designed for data science, which can make your work with data much more efficient and effective.
#
# So, let's not wait any longer and dive into the exciting world of Python programming.

# %% [markdown]
# ###Why Python 🐍
# Python is a good choice for beginners in data science for several reasons.
#
# 1. Python has a simple and easy-to-learn syntax that is designed to be readable and resembles the English language. This makes it easy for beginners to write code and understand what is happening in their code.
# 2. Python has a vast array of libraries and tools that are specifically designed for data science, including NumPy, Pandas, Matplotlib, and Scikit-learn. These libraries are essential for data manipulation, visualization, and machine learning tasks.
# 3. Python has a large open source community that provides support, tutorials, and documentation, making it easier for beginners to learn and use Python for data science tasks.
# 4. Python is a flexible language that can be used for a wide range of data science tasks and can handle large datasets.
#
#
# Overall, Python's simplicity, vast array of libraries, open source community, and flexibility make it an excellent choice for beginners in data science.

# %% [markdown]
# Before we start with python, let's understand what enables us to communicate with the computer so well.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Understanding how human interacts with machine through code**
#
# Imagine the interaction between two people is like how a computer processes code. One person speaks, the other listens, and the brain processes it for a response. This is very similar to how a Python interpreter works when processing code.
#
# **Listening - The Ears:** When one person speaks, the other listens through their ears, which send signals to the brain for processing. In Python, the interpreter acts as the “ears” of your code, receiving the instructions you’ve written. Whether the code is user input, file data, or web data, the interpreter listens to it just like our ears capture sounds.
#
# **Processing - The Brain:**  Just as the brain processes sounds from the ear and turns them into thoughts and actions, the Python interpreter processes your code, converting it into binary instructions that the computer’s CPU can understand. The interpreter acts like the brain, making sense of what the code is telling the computer to do.
#
# **Forming Understanding - Thoughts:** Our brain takes the sensory signals and turns them into meaningful information for us to act upon. Similarly, the interpreter compiles and organizes your Python code into structured instructions that the computer can execute. It’s the point where raw code becomes actionable steps, just like how our thoughts drive our decisions.
#
# **Taking Action - Body Response:** Once our brain processes information, it sends signals to the body to take action—like moving or speaking. In Python, after the code is processed, the computer executes the instructions, performing the calculations, tasks, or actions you wrote, just as our body responds to what we hear and understand.
#
# In summary, the Python interpreter is like the ear of the system—it listens to your code, processes it like the brain, and sends it to the computer to execute actions, just as humans process and respond to information. This analogy simplifies how a Python interpreter helps computers understand and execute code, much like our brain makes sense of what we hear to respond effectively.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Where do we practice coding?
#
# ###IDE
# An Integrated Development Environment (IDE) is a software application that provides programmers with a comprehensive set of tools and features to write, debug, and test their code in a single interface. IDEs often include a text editor, a debugger, a compiler, and other features like autocomplete, syntax highlighting, and code formatting. IDEs are designed to make the coding process more efficient and productive by providing all the necessary tools and features in one place, which can save time and effort for developers. IDEs are commonly used for programming languages like Python, Java, C++, and many more.
#
# Few examples of IDE:
# * PyCharm
# * Spyder
# * IDLE
# * Jupyter
# * Visual Studio Code (VSCode):
# * Google Colab
#
# We'll be using Google Colab for our journey. Let's find out why.

# %% [markdown]
# ###Why Google Colab

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Google Colaboratory is a good choice of IDE for beginners for several reasons.
#
# 1. It is a web-based platform that does not require any installation or setup, making it easily accessible to anyone with an internet connection.
# 2. It offers a free environment for users to run and execute code, making it ideal for beginners who may not want to invest in expensive hardware or software.
# 3. It allows for collaborative work and sharing of code and notebooks, making it easy for beginners to work with others and get feedback on their work.
# 4. It comes with pre-installed libraries and tools commonly used in data science, such as NumPy, Pandas, and Matplotlib, making it easy for beginners to start working on their projects without having to worry about setting up their environment.

# %% [markdown]
# ###Google Colab Basics
# Google Colaboratory (also known as Google Colab or simply Colab) is a cloud-based platform provided by Google that allows users to write, run, and share code in a Jupyter notebook environment. Colab offers free access to GPUs, which makes it an attractive tool for machine learning and deep learning practitioners.
#
# The toolbar in Colab provides access to a variety of tools that are useful when working with notebooks. Here is a brief overview of some of the key features:
#
# **File operations**: The toolbar allows you to create new notebooks, open existing ones, save your work, and download notebooks in various formats.
#
# **Runtime options**: You can use the toolbar to start and stop the notebook's runtime environment, which determines the computing resources available to your notebook.
#
# **Code execution**: The toolbar includes buttons that allow you to execute code cells in your notebook. You can also use the keyboard shortcuts Shift+Enter to execute the current cell and move to the next one or Ctrl+Enter to execute the current cell and remain on it.
#
# **Cell operations**: The toolbar provides options to insert new cells, delete existing ones, move cells up or down, and merge cells.

# %% [markdown]
# ###Let's go ahead and run our very first code. Excited? 😎

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# **Wondering what happened in the backend of this code?**
#
# A **Interpreter** in Python, or any programming language, is like a translator for computers. It takes the human-readable code that a programmer writes and turns it into something the computer can understand and execute.
#
# Here's how it works in simple terms:
#
# 1. **Writing Code**: First, a programmer writes code in a high-level language like Python. This code is easy for humans to read and write because it uses words and structures that make sense to us.
#
# 1. **Compilation**: When the programmer is ready to run their program, the Python Interpreter comes into play. The Interpreter is a special program that reads the Python code and translates it into a lower-level language called "machine code" or "bytecode." This lower-level language is like the computer's native language, and it can be executed very quickly.
#
# 1. **Errors and Optimization**: The Interpreter checks the code for any mistakes or errors. If it finds any, it will report them to the programmer, so they can fix the issues.
#
# 1. **Execution**: Once the code is error-free and optimized, it's ready to be executed by the computer. The computer can now understand the translated code and perform the tasks described in the original Python code.
#
# So, in a nutshell, a Python Interpreter is like a bridge between human-readable code and the computer's language. It takes our instructions, translates them into a format the computer can work with, and ensures everything is correct and efficient before the program runs. It's a crucial part of the software development process, allowing us to turn our ideas into functional software.

# %% [markdown]
# ####Importance of Commenting your Codes

# %% [markdown]
# Commenting code is an essential practice in software development. It involves adding explanatory remarks within the source code to provide context, explanations, or documentation about the code. This helps other developers (including your future self) understand the purpose, functionality, and logic of the code. Here are some reasons why commenting code is important:
#
# * Code Readability and Understandability: Well-commented code is easier to read and understand. It provides context and explanations that make it easier for other developers (or even yourself in the future) to grasp the code's logic and functionality.
#
# * Collaboration and Teamwork: When working on projects with other developers, clear comments facilitate collaboration. They allow team members to understand each other's code and make it easier to integrate different components of a project.
#
# * Debugging and Troubleshooting: Comments can be invaluable during the debugging process. They can provide insights into the author's intentions, making it easier to identify and fix bugs.
#
# * Documentation: Comments serve as a form of documentation for the codebase. They explain why certain decisions were made, the purpose of specific functions or blocks of code, and any important considerations.
#
# Maintenance and Updates: When returning to code after some time, comments can help you quickly reacquaint yourself with the codebase, reducing the time it takes to make updates or improvements.

# %% [markdown]
# In Python, there are several ways to add comments to your code:
#
# 1. Single-line Comments: Use the # symbol to create a single-line comment. Anything following # on the same line is treated as a comment.

# %%
# This is a single-line comment

# %% [markdown]
# 2. Multi-line Comments (String Literals): You can also use triple quotes ''' or """ to create multi-line comments. While this is not a standard way of commenting, it can serve the purpose.

# %%
'''
This is a multi-line comment.
It spans multiple lines.
'''

# %% [markdown]
# 3. Inline Comments: You can add comments on the same line as code. However, it's generally recommended to use these sparingly and only for very short, self-explanatory comments.

# %%
x = 5  # This is an inline comment

# %% [markdown]
# #### Numeric Data Types we Will Encounter in Python

# %% [markdown]
# We will be focusing on two main numeric data for the time being:
#
# **Integers**: Integers (or ints) are whole numbers without decimal points. In Python, integers can be positive, negative, or zero. They can be created by writing a number without a decimal point or by using the int() function.
#
# **Floats**: Floats are numbers with decimal points. In Python, floats can be positive, negative, or zero. They can be created by writing a number with a decimal point, by using scientific notation (e.g. 1.23e-4), or by using the float() function.
#
# **Booleans**: Boolean is a data type in Python that can have two values: True or False, used for logical operations.
#
# Python also supports other numeric data types, such as complex numbers, bool for boolean values (True or False) and decimal for fixed-precision decimal values. Additionally, Python provides a rich set of operators and functions for performing arithmetic operations and other manipulations on numeric data.

# %% [markdown]
# ### Let's talk about numbers!
#
# * A lot many different types of numbers are supported in Python like integers (int type), real numbers (float type), complex numbers. We will mostly use integer and floating point numbers.
#
#
# * Integers are just whole numbers, positive or negative. For example: 2 and -2 are examples of integers.
#
#
# * Floating point numbers in Python are notable because they have a decimal point in them, or use an exponential (E) to define the number. For example 2.0 and -2.1 are examples of floating point numbers. 4E2 (4 times 10 to the power of 2) is also an example of a floating point number in Python.
#
#
# * In computing, floating-point arithmetic is arithmetic using formulaic representation of real numbers as an approximation to support a trade-off between range and precision. You can always control the number of digits coming after the decimal, hence they are called floating-point numbers
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Basic Arithmetic
# Let's explore some basic arithmetic operations. Run the code cells to see the answers come to life!

# %%
# Addition
2+1
# Out:
# 3

# %%
# Subtraction
2-5
# Out:
# -3

# %%
# Multiplication
2*2
# Out:
# 4

# %%
# Division
3/2
# Out:
# 1.5

# %%
# Exponential
2**3
# Out:
# 8

# %%
# Order of Operations followed in Python
2 + 10 * 10 + 3
# Out:
# 105

# %% [markdown]
# ## <u>Arithmetic Precedence</u>

# %% [markdown]
# ![dffd.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **📖 Do you Know 📖**
#
# In Python, the order of operations follows the PEMDAS rule, which is an acronym to help remember the sequence of operations:
#
# 1. **P - Parentheses**:
#     - Operations enclosed in parentheses are performed first. Nested parentheses are evaluated from the innermost level to the outermost.
# 2. **E - Exponents**:
#     - After parentheses, exponentiation is performed next. This includes powers and square roots.
# 3. **M - Multiplication** and **D - Division**:
#     - These operations are performed next and are of equal precedence. They are executed from left to right. Division includes true division (**`/`**), floor division (**`//`**) and Modulo (**%**) . (You'll learn about the differences soon enough).
# 4. **A - Addition** and **S - Subtraction**:
#     - Finally, addition and subtraction are performed, also from left to right. They are of equal precedence.
#
# Python adheres to this order of operations, which is consistent with the standard mathematical conventions. Understanding PEMDAS is crucial for writing correct expressions in Python, as it dictates how complex expressions will be evaluated and in what sequence the operations will occur.

# %% [markdown]
# ### Let us do a small hands-on coding question:
# An operator working behind the scoreboard of a inter cohort AlmaBetter cricket tournament, is responsible for updating the scores and points of each team. However, the operator is currently facing a challenge. He has been tasked with updating the total number of points gained by Team London, but he does not possess the necessary programming skills to complete this task.
# According to the tournament's rules, teams are awarded the following points based on the outcome of a match:
#
# * wins: 3 points
# * draws: 1 point
# * losses: 0 points
#
#
#
#
# Team London has played **9 matches** in this tournament. They won **6 matches**, lost **2 matches** and **drew 1**.
# The operator is in need of assistance to calculate the total number of points earned by Team London. As a python expert adept with knowledge of integer, floats and boolean, you can help the operator by writing a solution for the following problem.
#
# What would your approach be?

# %%
#1. Define your fixed values:
# wins = 3 Points
# draws = 1 Points
# losses = 0 Point

# %%
#2. Calculate the total points gained by Team London
london_points = (6*3)+(2*0) + (1*1)

# %%
# 3. Print the variable london_points
print(london_points)
# Out:
# 19

# %% [markdown]
# ### **Activity: Guess the word**
#
# **Imagine you are on a treasure hunt to find the hidden treasure. To reach the treasure, you must solve a series of riddles.**

# %% [markdown]
# 1. I am a basic data type in Python,
#
#   Storing whole numbers is my function.
#
#   Positive, negative, or even zero,
#
#   In the world of math, I'm a hero.
#
#   What am I?
#
#
# 2. I am an operator of arithmetic, you see,
#
#   Basic math operations are what I decree.
#
#   With addition, I join numbers in glee,
#
#   And subtraction, I take some away with glee.
#
#   Multiplication makes numbers grow in size,
#
#   While division, the opposite, makes them minimize.
#
#   What am I?

# %% [markdown]
# #### **Answers:**

# %% [markdown]
# 1.  In Python, the int data type is used to represent whole numbers, both positive and negative, including zero.
#
#   ```
#   # Example of creating an integer variable
#   my_integer = 42
#   ```
#
#
#
#
# 2. The answer to the riddle is:
#
#   Operator (+, -, *, /)
#
#   The riddle refers to the basic arithmetic operators in Python:
#
# * Addition: The + operator adds numbers together.
# * Subtraction: The - operator subtracts one number from another.
# * Multiplication: The * operator multiplies numbers.
# * Division: The / operator divides one number by another.
#
#   ```
#   # Example of using the arithmetic operators
#   addition_result = 5 + 3    # 5 plus 3 equals 8
#   subtraction_result = 10 - 2  # 10 minus 2 equals 8
#   multiplication_result = 4 * 6  # 4 times 6 equals 24
#   division_result = 16 / 4  # 16 divided by 4 equals 4.0
#
#   ```

# %% [markdown]
# ### What is a Variable?
#
# ###  VARIABLES are entities which help us store information and retrieve it later.
#
#  * A variable with a fixed name can store information of nature like numeric, textual, boolean etc.
#
#
#  * A Python variable is a reserved memory location to store values. In other words, a variable in a python program gives data to the computer for processing.
#
#
#  * The type of data contained in a variable can be changed at user's will.

# %%
# You can store numbers in variables.
# The standard rule is you write the variable name followed by = sign and the value it will take
x=5

# %%
print(x)
# Out:
# 5

# %%
y=6.4
y
# Out:
# 6.4

# %%
print(y)
# Out:
# 6.4

# %% [markdown]
# ### Basic Arithmetic operations we can do on x and y. Later we will be doing operations on thousands of such numbers in one go!

# %%
# Addition
z = x+y

print(z)
# Out:
# 11.4

# %%
# Multiplication
z = x*y

print(z)  # Print the variable z
type(z)   # Get the data type of variable z
# Out:
# 32.0
# float

# %%
# Division
z = x/y

print(z) # Print the variable z
type(z)  # Get the data type of variable z
# Out:
# 0.78125
# float

# %%
# Subtraction
z = x-y

# Use the in-built print function to print the variable
print(z)
# Out:
# -1.4000000000000004

# %%
# Modulo operator
y=5
x=3

# %%
# PEMDAS nostalgia
some_random_operation =(x+y)/y + (y-x)*x

print(some_random_operation)
type(some_random_operation)
# Out:
# 7.6
# float

# %% [markdown]
# ### **Let's practice the above problem while using variables and replacing the value with variables.**

# %%
#1. Define your fixed values:
wins = 3
losses = 0
draws = 1


total_win = 6
total_loss = 2
total_draw = 1

# %%
#2. Calculate the total points gained by Team London
london_points = (total_win * wins) + (total_loss * losses) + (total_draw * draws)

# %%
# 3. Print the variable london_points
print(london_points)
# Out:
# 19

# %% [markdown]
# Too Simple !!! Right👌
#
# Python is too simple to learn and implement. Python is nothing but the machine translation of human calculations in a logical way.

# %% [markdown]
# ####  Rules for naming a variable in Python
# ![image.png](data:image/png;base64,...)
# * Variables names must start with a letter or an underscore like _ product , product_
#
#
# * The remainder of your variable name may consist of letters, numbers and underscores
#
#
# * spacy1, pyThon,machine_learning are some valid variable names
#
#
# * Names are case sensitive.
#
#
# * case_sensitive, CASE_SENSITIVE, and Case_Sensitive are each a different variable.
#
# * It's a best practice to create a variable that should be coherent with the context you are working on. Let's say you are working with fruit data; the variable name should be "fruit" or "fruit_mango."

# %%
1oNone = 4
# Out:
#   File "<ipython-input-26-5af1d05f4ba0>", line 1
#     1oNone = 4
#     ^
# SyntaxError: invalid decimal literal

# %%
on one_abc = 5
# Out:
#   File "<ipython-input-27-411a8a0f9f9b>", line 1
#     on one_abc = 5
#        ^
# SyntaxError: invalid syntax

# %%
@lmabetter=42
# Out:
#   File "<ipython-input-28-bf11fe817d6c>", line 1
#     @lmabetter=42
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
_almabetter_=42

# %%
_almabetter@=42
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-b52f095e2aa1> in <cell line: 1>()
# ----> 1 _almabetter@=42
#
# NameError: name '_almabetter' is not defined

# %%
alma#better=42
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-e2ee6552fe7d> in <cell line: 1>()
# ----> 1 alma#better=42
#
# NameError: name 'alma' is not defined

# %%
1almabetter=42
# Out:
#   File "<ipython-input-32-c445d12df8df>", line 1
#     1almabetter=42
#     ^
# SyntaxError: invalid decimal literal

# %%
list=5

# %% [markdown]
# Things didn't go very well there right?
# Let's see why

# %% [markdown]
# * Names cannot begin with a number. Python will throw an error when you try to do so
#
#
# * Names can not contain spaces, use _ instead
#
#
# * Names can not contain any of these symbols:
#
#       :'",<>/?|\!@#%^&*~-+
#
#
# * It is considered best practice that names are lowercase with underscores
#
#
# * Avoid using Python built-in keywords like `list`, `str` , `def`, `try` etc. We will talk more about such conventions later on

# %% [markdown]
# ### Let us practice another hands-on coding question:
# Imagine you are a data analyst at a nutrition bar manufacturing company. Your department head approaches you with a question. The company produces a nutrition bar that contains **50g of raisins, 60g of almonds, and 20g of apricots**. The head of the manufacturing department wants you to create an ingredient percentage list for the nutrition bar using python.
#
# Equipped with the knowledge of int, float and booleans in python, how would you approach this situation?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Calculate the percentage of raisins and print the variable
rai_sins=50/(50+60+20)*100
print(rai_sins)
# Out:
# 38.46153846153847

# %%
# Calculate the percentage of almonds and print the variable
almonds=60/(50+60+20)*100
print(almonds)
# Out:
# 46.15384615384615

# %%
# Calculate the percentage of apricots and print the variable

apricots=20/(50+60+20)*100
print(apricots)
# Out:
# 15.384615384615385

# %% [markdown]
# See how handy this knowledge can be? ✨

# %% [markdown]
# ###Introduction to Booleans

# %% [markdown]
# Booleans, or true ✅ /false ❌ values, are an essential part of programming, and Python is no exception! 🙌
#
# In real life, we often make decisions based on whether something is true or false. For example, if it's raining outside, we might decide to take an umbrella. In programming, we use Booleans to make decisions too! We can write code that checks if something is true or false and then does something based on the answer.
#
# For instance, think about a login page on a website. When a user enters their username and password, the program needs to check whether the information is correct or not. If it's correct, the program will let the user log in, and if it's incorrect, the program will deny access. This is just one example of how Booleans are used in real-world applications. 🔑
#
# Overall, Booleans are a simple yet powerful tool that allows us to make decisions in our code based on whether something is true or false. So, understanding Booleans is a fundamental aspect of programming, and mastering them can help you build amazing applications! 🚀

# %% [markdown]
# ###Boolean Variables
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Comparison Operators
#
# * These operators will allow us to compare variables and output a Boolean value (True or False).
#
#
# * If you have any sort of background in Math, these operators should be very straight forward.
#
#
# * First we'll present a table of the comparison operators and then work through some examples:
#
#
# * In the table below, a=3 and b=4.
#
# <table class="table table-bordered">
# <tr>
# <th style="width:10%">Operator</th><th style="width:45%">Description</th><th>Example</th>
# </tr>
# <tr>
# <td>==</td>
# <td>If the values of two operands are equal, then the condition becomes true.</td>
# <td> (a == b) is not true.</td>
# </tr>
# <tr>
# <td>!=</td>
# <td>If values of two operands are not equal, then condition becomes true.</td>
# <td>(a != b) is true</td>
# </tr>
# <tr>
# <td>&gt;</td>
# <td>If the value of left operand is greater than the value of right operand, then condition becomes true.</td>
# <td> (a &gt; b) is not true.</td>
# </tr>
# <tr>
# <td>&lt;</td>
# <td>If the value of left operand is less than the value of right operand, then condition becomes true.</td>
# <td> (a &lt; b) is true.</td>
# </tr>
# <tr>
# <td>&gt;=</td>
# <td>If the value of left operand is greater than or equal to the value of right operand, then condition becomes true.</td>
# <td> (a &gt;= b) is not true. </td>
# </tr>
# <tr>
# <td>&lt;=</td>
# <td>If the value of left operand is less than or equal to the value of right operand, then condition becomes true.</td>
# <td> (a &lt;= b) is true. </td>
# </tr>
# </table>

# %% [markdown]
# * Python  comes with Booleans (with predefined True and False displays that are basically just the integers 1 and 0). It also has a placeholder object called None. Let's walk through a few quick examples of Booleans (we will dive deeper into them later in this course).

# %%
# Set object to be a boolean
boolean_variable = False
type(boolean_variable)
# Out:
# bool

# %%
#Show
boolean_variable
# Out:
# False

# %% [markdown]
# ### Equal

# %%
2 == 3
# Out:
# False

# %%
2==0
# Out:
# False

# %% [markdown]
# * <u> Note that <code>==</code> is a comparison operator, while <code>=</code> is an assignment operator. </u>

# %%
2=3 #'=' is an assignment operator. Using it to compare values would result in error
# Out:
#   File "<ipython-input-41-88175c408298>", line 1
#     2=3 #'=' is an assignment operator. Using it to compare values would result in error
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %% [markdown]
# ### Not equal

# %%
2!=0
# Out:
# True

# %%
2!=2
# Out:
# False

# %% [markdown]
# ### Greater than

# %%
a=3
b=2
a> b
# Out:
# True

# %%
a == 3
# Out:
# True

# %%
b > 4
# Out:
# False

# %% [markdown]
# ### Less than

# %%
10 < 45
# Out:
# True

# %%
4 < 2
# Out:
# False

# %% [markdown]
# ### Greater than or equal to

# %%
3 >=2
# Out:
# True

# %%
4 >= 4
# Out:
# True

# %% [markdown]
# ### Less than or equal to

# %%
3 <= 0
# Out:
# False

# %%
1 <= 2
# Out:
# True

# %% [markdown]
# ### **Activity: True or False**
#
# 1. In Python, variable names cannot start with a number.
#
# 2. It is good practice to use special characters like '@' or '$' in Python variable names.
#
# 3. Python is not a case-sensitive language, so "variable" and "Variable" are considered the same.
#
# 4. "is" and "not" are Python's boolean operators.
#
# 5. The values of a boolean variable in Python can only be True or False (with an uppercase first letter).
#
# 6. The "and" operator in Python returns True if both operands are True.

# %% [markdown]
# #### **Answers:**

# %% [markdown]
# 1. True: Variable names in Python must start with a letter (a-z, A-Z) or an underscore (_), not with a number.
#
# 2. False: It is not recommended to use special characters like '@' or '$' in Python variable names. Stick to letters, numbers, and underscores.
#
# 3. False: Python is case-sensitive, so "variable" and "Variable" are treated as different variable names.
#
# 4. True: "is" and "not" are boolean operators in Python used for identity and negation, respectively.
#
# 5. True: In Python, boolean variables can only take the values True or False, both with an uppercase first letter.
#
# 6. True: The "and" operator returns True only if both operands are True.

# %% [markdown]
# ### Phew! We made it

# %% [markdown]
# In conclusion, we have covered the fundamentals of Python programming in this lesson. We hope that you now have a basic understanding of the language and are eager to continue learning. Remember, practice is key when it comes to programming, so we encourage you to experiment with the concepts we have covered today.
#
# Infact go attempt this assignment right away. With things you've learned today, it should be a breeze!
#
# As we move forward, we will delve deeper into the intricacies of Python programming, and we encourage you to stay curious and engaged in the lessons to come. If you have any questions or concerns, do not hesitate to reach out to us for further assistance.

# %% [markdown]
# # **✅ Summary ✅**

# %% [markdown]
# ## **What did you learn?**
#
# * 🔧 IDEs provide programming facilities and combine common development tasks into a single application.
# * 🐍 Python is a versatile and easy-to-learn programming language commonly used in data science due to its powerful libraries.
# * 📊 Google Colab is a popular cloud-based Python development environment commonly used for data science and machine learning projects.
# * 🔢 Python has built-in data types, including integers, floats & Booleans that make it easy to work with different kinds of numeric data.
# * 💻 Variables are used to store values in Python and must follow certain naming rules to make code readable and easy to understand.

# %% [markdown]
# ### **Best Practices/Tips to remember:**
#
# 1. **Write readable code:** Python is known for its readability, so it's important to write code that is easy to read and understand. Use meaningful variable names, add comments, and format your code consistently.
# 2. **Use code completion:** Most IDEs have a code completion feature that can save you time by automatically completing your code as you type. This can help you avoid syntax errors and make it easier to find the right function or method.
# 3. **Use debugging tools:** IDEs have built-in tools that allow you to step through your code, set breakpoints, and inspect variables. These tools can help you identify and fix bugs more quickly.
# 4. **Use version control:** Web-based development environments like Google Colab and Jupyter Notebook can integrate with version control systems like Git, which allows you to keep track of changes to your code and collaborate with others.
# 5. **Make use of Plugins and extensions:** IDEs usually have a lot of plugins and extensions that can help you to add new functionality to your development environment. Some of these plugins can help you to improve your productivity.
# 6. **Use PEP 8:** PEP 8 is a style guide for Python code that provides guidelines for writing readable and consistent code. Following these guidelines can make it easier for others to understand and maintain your code.
#
# ### **Shortcomings:**
#
# 1. **Speed**: Python is an interpreted language, which can make it slower than compiled languages like C or C++.
# 2. **Memory management:** Python's memory management can be less efficient than languages like C or C++, which can lead to memory leaks and performance issues.
# 3. **Concurrency**: Python's Global Interpreter Lock (GIL) can make it challenging to take full advantage of multi-core processors.
# 4. **Error-prone**: Python's dynamic nature can make it more prone to errors, especially regarding type checking.
# 5. **Limited debugging capabilities:** Some IDEs for Python may not have advanced debugging features, such as the ability to step through code, set breakpoints, and inspect variables.

# %% [markdown]
# # **➕ Enhance your Knowledge ➕**

# %% [markdown]
# ![as.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##<u> History of Python

# %% [markdown]
# 🐍 Python is a popular programming language that was created in the late 1980s by Guido van Rossum while he was working at the Centrum Wiskunde & Informatica (CWI) in the Netherlands. 🇳🇱
#
# 🚀 In 1991, van Rossum released the first version of Python, which was inspired by the ABC language and designed to be easy to read and write. The name "Python" was inspired by the British comedy group Monty Python, which van Rossum was a fan of. 🎭
#
# 🌎 Python quickly gained popularity in the scientific and academic communities, as well as among hobbyists and developers. It was praised for its clean syntax, readability, and ease of use. 📈
#
# 💻 Over the years, Python has continued to evolve and improve, with new features and modules being added to the language. One of the most significant updates was the release of Python 3 in 2008, which introduced several important changes and improvements, including better Unicode support and a more consistent syntax. 🆕
#
# 👨‍💻 Today, Python is one of the most widely used programming languages in the world, with a thriving community of developers and users. It is used for everything from web development and data analysis to machine learning and artificial intelligence. 🌐
#
# 👍 Python's popularity can be attributed to its simplicity, versatility, and power. It is an accessible language for beginners, yet powerful enough for advanced users to build complex applications. Python's community and ecosystem are also strong, with a wealth of libraries, frameworks, and tools available to help developers. 🔧

# %% [markdown]
# ## <u>Other Programing Languages similar to Python

# %% [markdown]
# 1. Ruby 🧱
#
# Ruby is a dynamic, object-oriented programming language that shares many similarities with Python. Both languages emphasize simplicity, readability, and developer productivity. Ruby is often used for web development, and is the primary language behind the popular web framework Ruby on Rails.
#
# 2. JavaScript 🌐
#
# JavaScript is a high-level, dynamic programming language that is commonly used for web development. Like Python, JavaScript is easy to learn and has a simple syntax, and is often used for scripting and automation tasks. JavaScript is also an interpreted language, meaning that it can be run directly in a web browser without the need for compilation.
#
# 3. Perl 🐪
#
# Perl is a high-level, general-purpose programming language that shares many similarities with Python. Like Python, Perl is easy to learn and has a simple syntax, and is often used for text processing and system administration tasks. Perl is known for its powerful regular expression engine and its flexibility, making it ideal for a wide range of applications.
#
# 4. Java ☕️
#
# Java is a general-purpose, object-oriented programming language that is widely used for enterprise development. While Java has a more complex syntax than Python, it shares many similarities in terms of its focus on readability, maintainability, and performance. Java is known for its platform independence, which allows developers to write code once and run it on any platform that supports Java.
#
# 5. Julia 📊
#
# Julia is a high-level, high-performance programming language that is designed for numerical and scientific computing. Like Python, Julia is easy to learn and has a simple syntax, and is often used for data analysis, machine learning, and scientific computing. Julia is known for its speed and performance, and is often used for complex computations that require high-level abstractions and numerical precision.
#
# Each of these programming languages has its own unique features and strengths, but all share a focus on simplicity, readability, and ease of use. Whether you're building web applications, analyzing data, or working on large-scale enterprise systems, there's a programming language that's right for your needs.

# %% [markdown]
# ## <u>Python Syntax</u>

# %% [markdown]
# Python is a high-level programming language widely used for web development, data analysis, artificial intelligence, and other applications. The syntax of Python is simple, readable, and easy to learn.
#
#
# Syntax is the rule that defines a program's writing and structure.
#
# Some of the critical components of python structure include:
#
# - Data types → Numbers, String, List, Tuple, Set, Dictionary
# - Operators → Arithmetic, Relational
# - Variables
# - Identifiers
# - Functions
# - Modules
# - Control Flow

# %% [markdown]
# Python's syntax is designed to be easy to read and understand, with a simple and consistent structure. Here are some examples of common elements of Python's syntax and how they are used:
#
# - **Variables**: Variables in Python are used to store data. You can assign a value to a variable using the assignment operator (=). For example, the following code assigns the value "Hello, World!" to the variable **`message`**:
#
# ```python
# message = "Hello, World!"
# print(message)
#
# # It will print: Hello, World!
# ```
#
# - **Data types**: Python has several built-in data types, including integers, floats, strings, and booleans. For example, the following code assigns an integer, a float, a string, and a boolean value to four different variables:
#
# ```python
# x = 5  # integer
# y = 3.14  # float
# name = "John"  # string
# is_student = True  # boolean
# ```
#
# - **Operators**: Python has several built-in operators, including arithmetic operators (e.g., +, -, *, /, %), comparison operators (e.g., ==, !=, >, <, >=, <=), and logical operators (e.g., and, or, not). For example, the following code uses the + operator to add two numbers and the == operator to compare two values:
#
# ```python
# x = 5
# y = 3
# z = x + y
# print(z)  # 8
#
# a = "Hello"
# b = "World"
# c = a == b
# print(c)  # False
# ```
#
# - **Identifiers:**  In Python, an identifier is a name given to a variable, function, class, module, or any other object. Identifiers are used to refer to these objects in the code. There are some rules and conventions to follow when naming identifiers in Python:
# 1. Identifiers can contain letters, numbers, and the underscore (_) character.
# 2. Identifiers cannot start with a number.
# 3. Identifiers cannot contain spaces.
# 4. Python has some reserved keywords that cannot be used as identifiers. (e.g. for, if, else, etc).
# 5. Python is case-sensitive, so the identifiers x and X are different. It is a good practice to follow the convention of using lowercase letters for identifiers, with words separated by underscores.
#
# **Valid identifier**
#
# - my_var
# - myVar
# - my_var_1
#
# **Invalid identifier**
#
# - 1_var - *starts with a number*
# - my var - *contains a space*
# - for - *a reserved keyword*
#
# - **Loops**: Python also has several looping structures that can be used to execute a block of code multiple times. For example, the "for" loop is used to iterate over a sequence of elements. The following code uses a "for" loop to print all the elements in a list:
#
# ```python
# fruits = ["apple", "banana", "orange"]
# for fruit in fruits:
#     print(fruit)
# ```
#
# - **Modules**: Python has a vast library, which is a collection of modules that provides additional functionality to the programming language. These modules can be imported into the program using the "import" keyword. For example, the following code imports the "math" module and uses the "sqrt" function from it to find the square root of a number:
#
# ```python
# import math
# x = 16
# result = math.sqrt(x)  # 4.0
# ```
#
# - **Control Flow**: Python has several control flow statements, including if-else, for loops, and while loops. For example, the following code uses an if-else statement to check whether a number is greater than or less than 10:
#
# ```python
# x = 15
# if x > 10:
#     print("x is greater than 10")
# else:
#     print("x is less than 10")
#
# ```
#
# - **Functions**: Python allows you to define your own functions using the **`def`** keyword. Functions take one or more arguments and return a value. For example, the following code defines a function that takes two arguments and returns their sum:
#
# ```python
# def add(x, y):
#     return x + y
#
# result = add(3, 5)
# print(result)  # 8
# ```
#
# Many built-in functions come with the Python language. These functions can perform various tasks, such as converting data types, manipulating strings, working with numbers, and more. Some of the most commonly used built-in functions in Python include **print(), type(), len(), str(),** etc.
#
# ---

# %% [markdown]
# # **Try it Yourself 📃**
#
# Are you ready to test your coding skills and gain practical experience? 🚀
#
# Take on the coding challenges linked to this lesson, designed to reinforce the concepts you've learned. You'll find them in your dashboard.
#
# Remember, coding is about applying knowledge to real-world problems, so dive in, experiment, and enjoy the process. Let’s grow and inspire each other as a community of passionate learners. Happy coding! 💻 😊

# %% [markdown]
# #### **🔴Go to the AlmaBetter IDE on the Practice Tab and try solving the coding questions present there.🔴**
