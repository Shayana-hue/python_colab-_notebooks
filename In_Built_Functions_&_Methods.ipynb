# %% [markdown]
# <a href="https://colab.research.google.com/github/Shayana-hue/python_colab-_notebooks/blob/python_colab_notebooks/In_Built_Functions_%26_Methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Session Flow:**
#
# 👨🏻‍🎓 Learning Objective:
#
# * Introduction
# * Theme
# * Primary Goals
#
# 📚🔍Exploring Built-in Functions
#
# - Understanding the concept of Built-in Functions in Python.
# - Discovering the wide range of Built-in Functions available.
# - Learning how to apply these functions to manipulate and process data.
#
# 🧩💻Practical Exercises with Functions
#
# - Hands-on exercises to apply Built-in Functions to different data types.
# - Using functions for numerical calculations, string manipulations, list operations, and more.
# - Understanding the versatility and utility of Built-in Functions.
# * Activity 1
#
# 🧠📖Understanding Methods
#
# - Introducing Built-in Methods associated with specific data types (e.g., strings, lists, dictionaries).
# - Exploring the concept of object-oriented programming and how methods are called.
# - Identifying the appropriate methods for different data types.
# * Activity 2
#
# 🛠️🧪Practical Use of Methods
#
# - Applying Built-in Methods to perform actions on data structures.
# - Utilizing methods to modify strings, lists, dictionaries, and other data types.
# - Hands-on coding exercises to reinforce the usage of Built-in Methods.
# * Activity 3
#
# 🏆⚡️Best Practices and Efficiency
#
# - Understanding the importance of choosing the right Built-in Functions and Methods.
# - Discussing best practices for code optimization and readability.
# - Tips and tricks to leverage the power of Built-in Functions and Methods effectively.
#
#
# 📝 Summary
#
# * What did we learn?
# * Shortcomings & Challenges
# * Best Practices & Tips
#
# 🔗 Enhance your Knowledge
#
# * Mnemonic
# * Additional Resources
#
# 🔍 Try it Yourself
#
# * Activities
# * Social Engagement

# %% [markdown]
# # **👨🏻‍🎓 Learning Objective 👨🏻‍🎓**

# %% [markdown]
# ###**Introduction**
# * 👩‍💻 In programming, an in-built function or method 🛠️ is like having a shortcut to pre-existing code 📦 included in a programming language's standard library. 📚
#
# * 👨‍💻 These functions and methods can be used by programmers to perform various operations on data types such as strings, numbers, lists, dictionaries, and more, without having to write the code for these operations from scratch. 🤓
#
# * 🚀 In-built functions and methods are essential to any programming language, as they allow developers to quickly and efficiently perform common tasks. 💪 They are also highly optimized and thoroughly tested, making them reliable and robust. 🧐
#
# 💻 In this lesson, we will explore the various in-built functions and methods available in Python 🐍. By the end of this article, you will have a solid understanding of the role of in-built functions and methods in programming and how they can help you write better code more efficiently. 🤩
#
# * Focus: Booleans, Strings, List, Tuples, Dictionaries, Sets

# %% [markdown]
# ### **Theme**
#
# In this thrilling adventure, we'll dive into the realm of Python, a versatile and powerful language that empowers you to create amazing things with code. 🐍💻 Get ready to explore In-Built Functions & Methods in python🧱
#
# In-Built Functions & Methods in Python form a powerful arsenal of tools that equip you to work efficiently with different data types. 🛠️🔍💻 Built-in Functions are pre-defined operations provided by Python, such as print(), len(), and sum(), designed to perform common tasks effortlessly. They allow you to manipulate, process, and analyze data with ease. On the other hand, Built-in Methods are functions that are specific to certain data types, like strings, lists, and dictionaries. 🧪📖📋 These methods, such as split(), append(), and keys(), enable you to interact with data structures in a more object-oriented manner. Throughout this lesson, you'll embark on practical exercises, discovering the extensive range of Built-in Functions and Methods available, and learn how to leverage them appropriately for different data types. By the end, you'll be equipped with the knowledge and skills to become a proficient Python data manipulator! 🚀🐍💡

# %% [markdown]
# ###**Primary Goals**
#
# * 🔎 Discovering the range of Built-in Functions and Methods available in Python.
# * 🤖 Applying these functions and methods to different data types through practical exercises.
# * 🧠 Gaining knowledge about which functions are appropriate for different data types.

# %% [markdown]
# # **📖 Learning Material 📖**

# %% [markdown]
# ## Introduction to In-Built Functions & Methods

# %% [markdown]
# Welcome to this lesson on inbuilt functions and methods in Python! 🎉🐍
#
# As you begin to develop your Python programming skills, you may have already come across a few built-in functions and methods in Python. In this lesson, we will explore the most commonly used built-in functions and methods that you may not be familiar with yet, including those that perform mathematical calculations, manipulate strings and lists, handle user input and output, and more. 🤖💻💡🛠️
#
# By the end of this lesson, you will have a comprehensive understanding of the most useful built-in functions and methods in Python, and you'll be able to use them to improve the efficiency and effectiveness of your Python code. 📈🔡📜🚀💯💪👨‍💻
#
# So, let's dive in and discover some new and exciting built-in functions and methods in Python! 💻🕵️‍♀️

# %% [markdown]
# ###Differences between Functions and Methods.
#
# 👉 Functions are like standalone tools that you can use to do a specific task. For example, 🖨️ print() is a function that you can use to show something on the screen. You call functions with parentheses ().
#
# 👉 Methods are like special tools that come with an object, like a string or a list. They are specific to that object, and you use them by putting a dot . after the object's name. For example, "hello".upper() is a method that makes the string all uppercase.
#
# 👉 Functions are like a hammer that you can use to drive a nail into a piece of wood. It doesn't matter what kind of wood it is or where the nail goes. You just use the hammer to do a general task.
#
# 👉 Methods are like a specialized tool that is made for a specific kind of wood. It might be a saw that can only cut a certain shape or a drill that can only make a certain size hole. You use the specialized tool to do a specific task on that specific wood.s

# %% [markdown]
# We'll explore the various data types in Python and the functions and methods that are related to each one.
#
# But before that, let's get familliar with an important method: input()

# %% [markdown]
# ##Taking inputs from user

# %% [markdown]
# ![giphy (3).gif](data:image/gif;base64,...)

# %% [markdown]
# In Python, you can take user inputs using the input() function. This function reads a line of text from the user, converts it into a string, and returns it as the result. Here's an example:

# %%
name = input("Enter your name: ")
print("Hello, " + name + "!")
# Out:
# Enter your name: Alex
# Hello, Alex!

# %% [markdown]
# In the above code, we use the input() function to read the user's name, and store it in the variable name. We then use string concatenation to print out a personalized greeting.
#
# It's important to note that the input() function always returns a string, even if the user enters a number. If you need to convert the user input into a different data type (such as an integer or a float), you can use the appropriate conversion function (int(), float(), etc.) to convert it. Here's an example:

# %%
age_str = input("Enter your age: ")
age = int(age_str)
print("You will be " + str(age + 1) + " next year.")
# Out:
# Enter your age: 30
# You will be 31 next year.

# %% [markdown]
# In the above code, we first use the input() function to read the user's age as a string, and store it in the variable age_str. We then use the int() function to convert age_str into an integer, and store it in the variable age. Finally, we use string concatenation to print out a message that tells the user how old they will be next year.

# %% [markdown]
# Awesome! With this knowledge, you can now create interactive programs that accept input from the user. 😃
#
# Next, let's delve into the various functions and methods that are associated with different data types.

# %% [markdown]
# ## General Purpose Functions

# %% [markdown]
# In Python, "general-purpose functions" typically refer to functions that are designed to perform a specific task or set of tasks that can be used in a wide range of applications or scenarios. These functions are not limited to a single, specialized use case but can be employed in various contexts. They are part of Python's standard library or created by developers to provide commonly needed functionality.
# Some of the common examples of general-purpose functions are:

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# 👋 Let's become familiar with Python functions and methods using the CRUD analogy. 💡 The **CRUD** analogy can help us understand how to create ➕, read 🔍, update 🔄, and delete ❌ data in Python.
#
# 👉 By using the **CRUD** analogy, we can learn how to perform basic operations on data in Python such as creating, reading, updating, deleting and few more actions as well.

# %% [markdown]
# ##CRUD
#
# CRUD stands for Create ➕, Read 🔍, Update 🔄, and Delete ❌. It's a common paradigm used in software development to describe the basic operations that can be performed on data. In Python 🐍, we can use functions and methods to implement these CRUD operations on different data structures.
#
# Here's a brief explanation of each CRUD operation in the context of Python.

# %% [markdown]
# ###**1.Create** ➕:
# In Python, we can create new objects or data structures using functions such as list() 📜, dict() 📖, set() 🛡️, tuple() 🧮, str() 📝, and int() 🔢.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Create a new list object
my_list = list([1, 2, 3])
print("my_list -", my_list)  # Output: my_list - [1, 2, 3]

# Create a new dictionary object
my_dict = dict({'name': 'John', 'age': 30})
print("my_dict -", my_dict)  # Output: my_dict - {'name': 'John', 'age': 30}

# Create a new set object
my_set = set(['apple', 'banana', 'cherry', 'apple'])
print("my_set -", my_set)  # Output: my_set - {'apple', 'banana', 'cherry'}

# Create a new tuple object
my_tuple = tuple((1, 2, 3))
print("my_tuple -", my_tuple)  # Output: my_tuple - (1, 2, 3)

# Create a new string object
my_string = str('Hello, world!')
print("my_string -", my_string)  # Output: my_string - Hello, world!

# Create a new integer object
my_int = int(42)
print("my_int -", my_int)  # Output: my_int - 42
# Out:
# my_list - [1, 2, 3]
# my_dict - {'name': 'John', 'age': 30}
# my_set - {'cherry', 'banana', 'apple'}
# my_tuple - (1, 2, 3)
# my_string - Hello, world!
# my_int - 42

# %% [markdown]
# ###Converting Data Types

# %% [markdown]
# 🎭 Type casting, also known as type conversion, is the process of converting a variable of one data type to another data type. This is a common practice in programming, as it allows us to manipulate and work with data in different ways.
#
# 🔢 For example, we might need to convert a string to an integer to perform mathematical operations on it, or we might need to convert a list to a set to remove duplicate elements.
#
# 🎭 Type casting can be done using built-in functions like str(), int(), float(), list(), set(), and tuple(), which convert variables from one data type to another.
#
# 🔢 It's important to note that type casting can result in a loss of data or precision, depending on the data types being converted. For example, when we convert a float to an integer, we lose the decimal portion of the number. Therefore, it's important to use type casting with care and understand its implications

# %%
# Type casting from int to str
my_int = 42
my_string = str(my_int)
print("Type casting from int to str:", type(my_int), type(my_string))
# Out:
# Type casting from int to str: <class 'int'> <class 'str'>

# %%
# Type casting from str to int
my_string = '42'
my_int = int(my_string)
print("Type casting from str to int:", type(my_string), type(my_int))
# Out:
# Type casting from str to int: <class 'str'> <class 'int'>

# %%
# Type casting from list to set

my_list = [1, 2, 3, 2, 1]
my_set = set(my_list)
print("Type casting from list to set:", type(my_list), type(my_set))
# Out:
# Type casting from list to set: <class 'list'> <class 'set'>

# %%
# Type casting from set to list

my_set = {1, 2, 3}
my_list = list(my_set)
print("Type casting from set to list:", type(my_set), type(my_list))
# Out:
# Type casting from set to list: <class 'set'> <class 'list'>

# %% [markdown]
# ###**2. Read** 🔍:
# We can use functions and methods to read or retrieve data from objects or data structures in Python.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Retrieving the length of a list
my_list = [1, 2, 3, 4, 5]
print("Length of my_list:", len(my_list))
# Out:
# Length of my_list: 5

# %%
# Retrieving the index of an element in a list
my_list = [10, 20, 30, 40, 50]
index = my_list.index(30)
print("Index of element 30:", index)
# Out:
# Index of element 30: 2

# %%
# Retrieving a value from a dictionary using get()
my_dict = {"name": "John", "age": 25, "city": "New York"}
age = my_dict.get("age")
print("Age:", age)
# Out:
# Age: 25

# %%
# Retrieving the index of a substring in a string
my_string = "Hello, world!"
index = my_string.find("world")
print("Index of 'world':", index)
# Out:
# Index of 'world': 7

# %%
# Retrieving the count of an element in a list
my_list = [1, 2, 3, 2, 1, 2, 3, 2, 1]
count = my_list.count(2)
print("Count of element 2:", count)
# Out:
# Count of element 2: 4

# %% [markdown]
# #### Other Methods used specifically for Dictionary in Read Operations:

# %% [markdown]
# #### **Dictionary Methods:**

# %% [markdown]
# * dict.keys() 🔑: returns a list of all the keys in the dictionary
# * dict.values() 💰: returns a list of all the values in the dictionary
# * dict.items() 📝: returns a list of all the key-value pairs in the dictionary
# * dict.get(key, default) 🆔: returns the value for the specified key, or the * default value if the key is not found

# %%
# Define a sample dictionary
my_dict = {"apple": 2, "banana": 3, "orange": 4}

# dict.keys()
print("Keys in the dictionary- ",list(my_dict.keys())) # output: dict_keys(['apple', 'banana', 'orange'])

# dict.values()
print("Values in the dictionary- ",list(my_dict.values())) # output: dict_values([2, 3, 4])

# dict.items()
print("Dictionary items- ",list(my_dict.items())) # output: dict_items([('apple', 2), ('banana', 3), ('orange', 4)])

# dict.get(key, default)
print("Fetching value corresponding to 'apple'- ",my_dict.get("apple", 0)) # output: 2
print("Fetching value corresponding to 'grape' (non existent)- ",my_dict.get("grape", 0)) # output: 0
# Out:
# Keys in the dictionary-  ['apple', 'banana', 'orange']
# Values in the dictionary-  [2, 3, 4]
# Dictionary items-  [('apple', 2), ('banana', 3), ('orange', 4)]
# Fetching value corresponding to 'apple'-  2
# Fetching value corresponding to 'grape' (non existent)-  0

# %% [markdown]
# Note that in the dict.keys(), dict.values(), and dict.items() functions, the output is a special dictionary object (e.g., dict_keys, dict_values, and dict_items). You can convert these to a regular list by wrapping them in a list() function, as we did in the example.

# %% [markdown]
# ###**3.Update** 🔄:
# We can use functions and methods to update or modify existing objects or data structures in Python.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 1. sorted() - Sorts a list object in ascending order

my_list = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3]
sorted_list = sorted(my_list)
print("Original list:", my_list)
print("Sorted list:", sorted_list)
# Out:
# Original list: [3, 1, 4, 1, 5, 9, 2, 6, 5, 3]
# Sorted list: [1, 1, 2, 3, 3, 4, 5, 5, 6, 9]

# %%
#2. append() - Adds a new element to the end of a list

my_list = [1, 2, 3, 4]
print("Original list:", my_list)
my_list.append(5)
print("List after appending 5:", my_list)
# Out:
# Original list: [1, 2, 3, 4]
# List after appending 5: [1, 2, 3, 4, 5]

# %%
# 3. update() - Adds or updates a key-value pair in a dictionary

my_dict = {"name": "John", "age": 30}
print("Original dictionary:", my_dict)
my_dict.update({"age": 31, "gender": "Male"})
print("Dictionary after updating:", my_dict)
# Out:
# Original dictionary: {'name': 'John', 'age': 30}
# Dictionary after updating: {'name': 'John', 'age': 31, 'gender': 'Male'}

# %%
# 4. replace() - Replaces a substring in a string with a new substring

my_string = "Hello, World!"
new_string = my_string.replace("World", "Python")
print("Original string:", my_string)
print("String after replacing:", new_string)
# Out:
# Original string: Hello, World!
# String after replacing: Hello, Python!

# %%
#5. extend() - Adds multiple elements to the end of a list

my_list = [1, 2, 3]
print("Original list:", my_list)
my_list.extend([4, 5, 6])
print("List after extending:", my_list)
# Out:
# Original list: [1, 2, 3]
# List after extending: [1, 2, 3, 4, 5, 6]

# %% [markdown]
# #### Other Methods for update operation:

# %% [markdown]
# **insert():** Adds an element at a specified position.

# %%
#Example:
ex = [1,2,3,3,5]
ex.insert(0,6)
print(ex)
# Out:
# [6, 1, 2, 3, 3, 5]

# %% [markdown]
# **setdefault():** Updates the dictionary with specified key-value pairs.

# %%
#Example:
ex = {'a' :1 , 'b':2}
ex.setdefault('a',"None")
# Out:
# 1

# %%
ex1 = {'a' :1 , 'b':2}
ex1.setdefault('c',"None")
# Out:
# 'None'

# %% [markdown]
# ### **4.Delete** ❌:
# We can use functions and methods to delete or remove objects or data structures in Python.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 1. del - Deletes a specific variable or object

a = 10
del a
print(a) # Would result in an error

# %%
# 2. remove() - Removes a specific element from a list

my_list = [1, 2, 3, 4, 5]
my_list.remove(3)
print(my_list)
# Out:
# [1, 2, 4, 5]

# %%
# 3. pop() - Removes and returns the last element of a list
my_list = [1, 2, 3, 4, 5]
print("my_list-", my_list)

# pop method removes the element at the specified and also returns it. So you can store that value in a variable as well
popped_element_last = my_list.pop() #pops last element by default
popped_element_3=my_list.pop(3) #pops element at index 3
print("popped element at last index-",popped_element_last)
print("popped element at index 3- ",popped_element_3)
print("final List -",my_list)
# Out:
# my_list- [1, 2, 3, 4, 5]
# popped element at last index- 5
# popped element at index 3-  4
# final List - [1, 2, 3]

# %%
#4.clear() - Removes all elements from a dictionary, set and list

my_dict = {'a': 1, 'b': 2, 'c': 3}
my_dict.clear()
print(my_dict)
# Out:
# {}

# %%
my_list=[1,2,3,4]
my_list.clear()
print(my_list)
# Out:
# []

# %%
my_set={1,2,3,4}
my_set.clear()
print(my_set)
# Out:
# set()

# %%
#5. discard() - Removes a specific element from a set, if it exists
my_set = {1, 2, 3, 4, 5}
my_set.discard(3)
print(my_set)
# Out:
# {1, 2, 4, 5}

# %% [markdown]
# ##Miscellaneous Functions and Methods

# %% [markdown]
# ###Strings

# %% [markdown]
# * 🔠 string.upper(): returns a copy of the string with all characters in upper case
# * 🔡 string.lower(): returns a copy of the string with all characters in lower case
# * 🆔 string.title(): returns a copy of the string with the first character of each word in title case (i.e. upper case)
# * 🔀 string.replace(old, new): returns a copy of the string with all occurrences of old replaced with new
# * 🔪 string.split(separator): returns a list of substrings separated by the specified separator
# * 🔗 string.join(iterable): returns a string that is the concatenation of the elements in the specified iterable, separated by the string string
# * 🔢 string.isnumeric(): returns True if all characters in the string are numeric, otherwise False

# %%
# Sample string
string = "alma better"
print("Original String ",string)
# Out:
# Original String  alma better
#
# Uppercase String: ALMA BETTER
#
# Lowercase String: alma better
#
# Titlecase String: Alma Better
#
# Original String: alma better
#
# New String: alma best
#
# List of words: ['alma', 'better']
#
# Joined String: alma-better

# %%
# Using upper() to convert string to all uppercase
upper_case = string.upper()
print("Uppercase String:", upper_case)
# Out:
# Uppercase String: ALMA BETTER

# %%
# Using lower() to convert string to all lowercase
lower_case = string.lower()
print("Lowercase String:", lower_case,)

# %%
# Using title() to convert the first character of each word to uppercase
title_case = string.title()
print("Titlecase String:", title_case)

# %%
# Using replace() to replace all occurrences of a substring with another substring
print("Original String:", string,'\n')
new_string = string.replace("better", "best")
print("New String:", new_string)

# %%
# Using split() to split a string into a list of substrings based on a separator
word_list = string.split(" ")
print("List of words:", word_list)

# %%
# Using join() to concatenate a list of strings into a single string with a separator
new_string = "-".join(word_list)
print("Joined String:", new_string)

# %% [markdown]
# ## Do you know? 🤔

# %% [markdown]
# You can use functions like min(),max() and operators like ">,>=,<,<=,==" etc on strings as well. But how do you think it works here?

# %%
animals=['Bear','bear']
print(max(animals))  #What do you think would be the result?

# %% [markdown]
# Wondering why "bear" is considered to be greater than "Bear" when comparing strings in Python? 🤔
#
# Well, it all comes down to how Python uses Unicode to compare strings for hierarchy.
#
# What is Unicode? 🌎💬
#
# Unicode is a standard that assigns a unique number to every character, symbol, and emoji in every language and writing system in the world. This makes it possible for computers to store, process, and communicate text in any language or script, including emojis!
#
# To find the Unicode of a character in Python, you can use the **ord('character')** method. And to generate a character corresponding to a Unicode, you can use the **chr('Unicode')** method. You need not worry about these now.
#
# So in the case of "bear" and "Bear," the lowercase "b" has a lower Unicode value than the uppercase "B," which is why "bear" is considered to be greater than "Bear" when comparing strings in Python.

# %%
print("Unicode for 'b'- ",ord('b'))
print("Unicode for 'B'- ",ord('B'))
# Out:
# Unicode for 'b'-  98
# Unicode for 'B'-  66

# %% [markdown]
# There are unicodes for every single characters you see on your screen. Even emojis!!
#
# Don't believe us? print the statement below:

# %%
print(chr(129528),"is greater than",chr(128059))
# Out:
# 🧸 is greater than 🐻

# %% [markdown]
# So. Do you see why "bear" is greater than "Bear"? 😉

# %% [markdown]
# ### **Let us practice hands-on coding question:**

# %% [markdown]
# Here is a string for you to work with:

# %%
statement= "arnav is writing a book titled 'python made easy'. His book is expected to release in March"

# %% [markdown]
# #### 1. Create a list containing the two sentences in the statement.

# %%
sentence_list=statement.split('.')
print(sentence_list)
# Out:
# ["arnav is writing a book titled 'python made easy'", ' His book is expected to release in March']

# %% [markdown]
# #### 2. The name 'arnav' is spelled wrong. Replace it with 'Arnav'.

# %%
statement=statement.replace('arnav','Arnav')
print(statement)
# Out:
# Arnav is writing a book titled 'Python Made Easy'. His book is expected to release in March

# %% [markdown]
# #### 3. The title of the book is not written in the correct cases as well. Make corrections there.

# %%
statement=statement.replace('python made easy','python made easy'.title())
print(statement)
# Out:
# Arnav is writing a book titled 'Python Made Easy'. His book is expected to release in March

# %% [markdown]
# #### 4. Reschedule the release of the book to month of your choice. Take input of month from the user and repalce it with "March" in the statement.

# %%
reschedule_month=input("Which month would you like to reschedule the launch to? ")
statement=statement.replace("March",reschedule_month)
print(statement)
# Out:
# Which month would you like to reschedule the launch to? Aril
# Arnav is writing a book titled 'Python Made Easy'. His book is expected to release in April

# %% [markdown]
# ###**Activity 1**
# # Guess the word

# %% [markdown]
# 1.  I am a method that replaces a specific substring in a string with a new substring. If you use me to change "sun" with "moon" in the sentence "The sun sets," a new enchanting sentence will appear. What method am I?
#
# 2. I am a method that cut a string into a list of different parts using a specified separator. If you use me to chop the sentence "I love python" using the space as the separator, the elements of the list will be revealed. What method am I?
#
# 3.  I am a method that checks if a string contains only digits. If you apply me to the string "12345," I will uncover the truth about its composition. What method am I?

# %% [markdown]
# #### **Answers**

# %% [markdown]
# 1. **Answer:** string.replace(old, new)
#   Explanation: The method string.replace(old, new) replaces a specific substring (old) in a string with a new substring (new). In this riddle, using replace("sun", "moon") on the sentence "The sun sets" will result in "The moon sets."
#
# 2. **Answer:** string.split(separator)
#   Explanation: The method string.split(separator) splits a string into a list of substrings using the specified separator. In this riddle, using split(" ") on the sentence "I love python" will produce the list ['I', 'love', 'python'].
#
# 3. **Answer:** string.isnumeric()
#   Explanation: The method string.isnumeric() checks if a string contains only numeric characters (digits). In this riddle, applying isnumeric() to the string "12345" will reveal that it contains only numeric characters.

# %% [markdown]
# ###Lists

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * list.insert(index, item) 👉: inserts an item at a specific index in the list
# * list.reverse() 🔄: reverses the order of the items in the list
# * list.copy() 📝: returns a copy of the list

# %%
# create a list
my_list = [4, 2, 8, 1, 6, 5]

my_list.insert(2, 7) # Syntax - my_list.append(index, element)
print("List after inserting item:", my_list,'\n')

my_list.reverse()
print("Reversed list:", my_list,'\n')

new_list = my_list.copy()
print("New copied list:", new_list,'\n')

# %% [markdown]
# ### **Let us practice hands-on coding question:**

# %% [markdown]
# 🎥 Suppose you have a collection of your favorite movies 🍿🎞️ and you want to keep track of them using a Python list 📜. You start with an empty list [] and keep adding new movies 🆕 to it. You also want to be able to remove movies ❌ that you have watched or no longer want to keep in your collection. Finally, you want to be able to count 🔢 how many movies you have in your collection and reverse the order of the list 🔄.

# %% [markdown]
# ![4109c3f1d362403a87c5ebfd4bb382ee.gif](data:image/gif;base64,...)

# %% [markdown]
# **🔴PROMPT: Ask the students to add in their own favourite movies and perform the task🔴**

# %%
# Start with an empty list
movie_collection =


# Add some movies to the collection using the append() method

# %%
# Print the current collection of movies

# %%
# Remove a movie from the collection using the pop() method


# Print After removing Pulp Fiction
print("After removing one movie:", movie_collection)

# %%
# Count how many movies are in the collection using the count() method

num_movies =
print("Number of movies:", num_movies)

# %%
# Reverse the order of the list using the reverse() method


#Print the reversed movie collection
print("Reversed movie collection:", movie_collection)

# %% [markdown]
# #### **Answer**

# %%
# Start with an empty list
movie_collection = []


# Add some movies to the collection using the append() method
movie_collection.append("The Godfather")
movie_collection.append("The Shawshank Redemption")
movie_collection.append("The Dark Knight")
movie_collection.append("Pulp Fiction")
movie_collection.append("Goodfellas")

# %%
# Print the current collection of movies

print("My Movie Collection:", movie_collection)
# Out:
# My Movie Collection: ['The Godfather', 'The Shawshank Redemption', 'The Dark Knight', 'Pulp Fiction', 'Goodfellas']

# %%
# Remove a movie from the collection using the pop() method

movie_collection.pop(3)  # remove "Pulp Fiction"
print("After removing Pulp Fiction:", movie_collection)
# Out:
# After removing Pulp Fiction: ['The Godfather', 'The Shawshank Redemption', 'The Dark Knight', 'Goodfellas']

# %%
# Count how many movies are in the collection using the count() method

num_movies = len(movie_collection)
print("Number of The Godfather movies:", num_movies)
# Out:
# Number of The Godfather movies: 4

# %%
# Reverse the order of the list using the reverse() method

movie_collection.reverse()
print("Reversed movie collection:", movie_collection)
# Out:
# Reversed movie collection: ['Goodfellas', 'The Dark Knight', 'The Shawshank Redemption', 'The Godfather']

# %% [markdown]
# ###**Activity 2**

# %% [markdown]
# #### **Pick the right one**

# %% [markdown]
# **Scenario 1:** Sarah has a list of fruits: ['apple', 'banana', 'orange']. She wants to add 'grape' to the end of the list.
# Which list method should she use?
#
# A) pop()
#
# B) append()
#
# C) copy()
#
# D) insert()
#
#
# **Scenario 2:** John has a list of numbers: [10, 20, 30, 40, 50]. He wants to remove the last element from the list.
# Which list method should he use?
#
# A) pop()
#
# B) append()
#
# C) copy()
#
# D) insert()
#
#
# **Scenario 3:** Emma has a list of colors: ['red', 'green', 'blue']. She wants to add 'yellow' after 'red'.
# Which list method should she use?
#
# A) pop()
#
# B) append()
#
# C) copy()
#
# D) insert()
#
#
# **Scenario 4:** Liam has a list of letters: ['a', 'b', 'c', 'd', 'e']. He wants to reverse the order of the elements in the list.
# Which list method should he use?
#
# A) pop()
#
# B) append()
#
# C) copy()
#
# D) reverse()

# %% [markdown]
# #### **Answers**

# %% [markdown]
# Scenario 1:
# **Answer:** B) append()
#
#   Explanation: The list method append() is used to add an element to the end of the list. In this scenario, Sarah can use append('grape') to add 'grape' to the end of the list of fruits.
#
# Scenario 2:
# **Answer:** A) pop()
#
#   Explanation: The list method pop() is used to remove and return the last element of the list. In this scenario, John can use pop() to remove the last element from the list of numbers.
#
# Scenario 3:
# **Answer:** D) insert()
#
# Explanation: The list method insert() is used to insert an element at a specific position in the list. In this scenario, Emma can use insert(1, 'yellow') to add 'yellow' after 'red' in the list of colors.
#
# Scenario 4:
# **Answer:** D) reverse()
#
# Explanation: The list method reverse() is used to reverse the order of elements in the list. In this scenario, Liam can use reverse() to reverse the order of the letters in the list.

# %% [markdown]
# ###Sets

# %% [markdown]
# * set.add(item) ➕: adds an item to the set
#
# * set.union(set2) 🔗: returns a new set with all items from both sets
# * set.intersection(set2) 🔍: returns a new set with only the items that are in both sets
# * set.difference(set2) ➖: returns a new set with items in the set that are not in set2
# * set.symmetric_difference(set2) ➖: returns a new set with items in either set or but not in both sets
# * set.copy() 📝: returns a copy of the set

# %%
# Create a set

fruits = {"apple", "banana", "cherry"}


#Adding another fruit to the set

fruits.add("orange")  # ➕ Adds an item to the set
print("Set after adding 'Orange'-",fruits)
# Out:
# Set after adding 'Orange'- {'orange', 'banana', 'cherry', 'apple'}

# %%
# Create another set
colors = {"red", "green", "orange"}


print("Union of two sets",colors.union(fruits))  # 🔀 Returns a set containing the union of sets

print("Intersection of two sets", colors.intersection(fruits))  # 🤝 Returns a set containing the intersection of sets

print("Difference of two sets",colors.difference(fruits))  # ➖ Returns a set containing the difference between two sets
# Out:
# Union of two sets {'orange', 'cherry', 'green', 'red', 'banana', 'apple'}
# Intersection of two sets {'orange'}
# Difference of two sets {'green', 'red'}

# %% [markdown]
# ### **Let us practice hands-on coding question:**

# %% [markdown]
# A store 🏪 sells different types of fruits 🍎🍌🍇🍓 in baskets 🧺. The storekeeper 🧑 keeps track of the availability of each fruit type in separate sets. The storekeeper wants to know which fruits are available in both baskets, which fruits are unique to each basket, and the total number of fruits available. 🤔

# %% [markdown]
# ![___-__.gif](data:image/gif;base64,...)

# %%
# Define sets for fruits in each basket
basket1 =
basket2 =

# Find the total number of fruits available

total_fruits =
print("Total number of fruits available:", total_fruits)

# Find fruits available in both baskets

both_baskets =
print("All the available fruits:", both_baskets)

# Find only the common fruits in both baskets

common_fruits =
print("Common fruits in both baskets:", common_fruits)

# Find fruits unique to each basket

unique_basket1 =
unique_basket2 =
print("Fruits unique to basket 1:", unique_basket1)
print("Fruits unique to basket 2:", unique_basket2)

# %% [markdown]
# #### **Answer**

# %%
# Define sets for fruits in each basket

basket1 = {'apple', 'banana', 'grape', 'orange'}
basket2 = {'banana', 'mango', 'pineapple', 'orange'}

# %%
# Find the total number of fruits available

total_fruits = len(basket1)+len(basket2)
print("Total number of fruits available:", total_fruits)
# Out:
# Total number of fruits available: 8

# %%
# Find fruits available in both baskets

both_baskets = basket1 | basket2
print("All the available fruits:", both_baskets)
# Out:
# All the available fruits: {'pineapple', 'grape', 'mango', 'apple', 'orange', 'banana'}

# %%
# Find only the common fruits in both baskets

common_fruits = basket1 & basket2
print("Common fruits in both baskets:", common_fruits)
# Out:
# Common fruits in both baskets: {'orange', 'banana'}

# %%
# Find fruits unique to each basket

unique_basket1 = basket1 - basket2
unique_basket2 = basket2 - basket1
print("Fruits unique to basket 1:", unique_basket1)
print("Fruits unique to basket 2:", unique_basket2)
# Out:
# Fruits unique to basket 1: {'grape', 'apple'}
# Fruits unique to basket 2: {'mango', 'pineapple'}

# %% [markdown]
# ###**Activity 3**

# %% [markdown]
# #### **Error Spotting**

# %% [markdown]
# 1. **Code:**
#
# ```
# set1 = {1, 2, 3}
# set2 = {3, 4, 5}
# result = set1.add(4)
# ```
# A) The use of set1.add(4) is incorrect as the add() method does not return a value.
#
# B) The use of set1.add(4) is incorrect because the element 4 already exists in set1.
#
# C) The use of set1.add(4) is correct and will add the element 4 to set1.
#
# D) The use of set1.add(4) is incorrect because the correct syntax is set.add(4).
#
# 2. **Code:**
#
# ```
# set1 = {1, 2, 3}
# set2 = {3, 4, 5}
# result = set1.intersection(set2)
# ```
# A) The use of set1.intersection(set2) is correct and will create a new set containing common elements from set1 and set2.
#
# B) The use of set1.intersection(set2) is incorrect because it modifies set1 directly instead of creating a new set.
#
# C) The use of set1.intersection(set2) is incorrect because the correct syntax is set1.intersection(set2).
#
# D) The use of set1.intersection(set2) is incorrect because the intersection() method can only be applied to two sets with the same elements.
#
#
# 3. **Code:**
#
# ```
# set1 = {1, 2, 3}
# set2 = {3, 4, 5}
# result = set1.difference(set2)
# ```
# A) The use of set1.difference(set2) is correct and will create a new set containing elements that are in set1 but not in set2.
#
# B) The use of set1.difference(set2) is incorrect because it modifies set1 directly instead of creating a new set.
#
# C) The use of set1.difference(set2) is incorrect because the correct syntax is set1.difference(set2).
#
# D) The use of set1.difference(set2) is incorrect because the difference() method can only be applied to two sets with the same elements.

# %% [markdown]
# #### **Answers**

# %% [markdown]
# 1. **Answer:** A
#
# Explanation: The add() method in sets does not return a value. It modifies the set in place by adding the specified element to the set. Therefore, using result = set1.add(4) would assign None to the result variable.
#
# 2. **Answer:** A
#
# Explanation: The intersection() method creates a new set containing the common elements from both sets without modifying the original sets. So, using set1.intersection(set2) is correct, and it will return a new set with the element [3].
#
# 3. **Answer:** A
#
# Explanation: The difference() method creates a new set containing elements that are in the first set but not in the second set without modifying the original sets. So, using set1.difference(set2) is correct, and it will return a new set with the elements [1, 2].

# %% [markdown]
# # **✅ Summary ✅**

# %% [markdown]
# ##What did you learn:
#
# 👉 In-built functions and methods 🛠️ in programming languages are pre-defined tools 💻 that provide standard functionality for everyday tasks and operations.
#
# 🕰️ They save time and reduce errors by providing ready-to-use functionality that can be implemented in various programs. 🚀
#
# 📚 Built-in functions are pre-defined functions that perform common tasks, while built-in methods are associated with a specific data type. 🔍
#
# 💪 Overall, built-in functions and methods are essential for programmers, as they offer a reliable and efficient way to implement standard functionality that can be used in many different programs. 🤓 This simplifies the coding process, making writing efficient, error-free code easier. ✅

# %% [markdown]
# ##**Best Practices/Tips**
#
# * 📚 Understand the documentation 📖: Before using any in-built function or method, it's essential to read the documentation to understand its parameters 📝, return values 🔄, and any other important details.
#
# * 👍 Use built-in functions and methods when possible 🛠️: Instead of writing your own functions, use in-built functions and methods whenever possible. They are often faster ⏩, more efficient 💪, and less prone to errors 🚫.
#
# * 💡 Know when to combine functions and methods 🔗: Sometimes, combining in-built functions and methods can save time and reduce code complexity. For example, using the split() method and the len() function together can quickly determine the number of words in a sentence.
#
# * 🔍 Be aware of version compatibility 🤔: Different versions of a programming language may have different in-built functions or methods. Ensure that the function or method you're using is compatible with the version of the language you're using.
#
# * 💻 Use appropriate data types 📊: In-built functions and methods are often associated with specific data types, such as strings 🔤, lists 📜, or dictionaries 📚. Use the appropriate data type to ensure that you can use the relevant in-built functions and methods.

# %% [markdown]
# ##**Shortcomings**
#
# * 🙅‍♀️ Limited functionality: In-built functions and methods may not always provide the functionality you need, and you may need to write your own function if you require a more complex operation.
#
# * 🙅‍♂️ No customization: In-built functions and methods cannot be customized to fit your specific needs, and you may need to write your own function if you require a different behavior or output format.
#
# * 💻 Inefficient for large datasets: In-built functions and methods may not be optimized for large datasets, and they may consume a lot of memory or take a long time to run. In these cases, you may need to write your own function or use a third-party library.
#
# * 🌐 Compatibility issues: Different versions of Python may have different in-built functions and methods, which may lead to compatibility issues when running code across different systems or environments.
#
# * 🤷‍♀️ Lack of error handling: In-built functions and methods may not always provide error handling, which can make it difficult to diagnose issues with your code. In these cases, you may need to write your own error handling logic.

# %% [markdown]
# By mastering the built-in methods and functions for data structures, you acquire the necessary skills to perform data manipulation, extraction, validation, and control flow. This knowledge serves as a foundation for working with conditional statements, indentations, and control structures, enabling you to write more powerful and effective programs. ✅🚀

# %% [markdown]
# # **➕ Enhance your Knowledge ➕**

# %% [markdown]
# ##**Mnemonic**
#
# 📖 Once upon a time, there was a software developer named Alex 👨‍💻 who was working on a project. He found himself writing a lot of code to perform common tasks, such as calculating the length of a sequence 📏, finding the maximum or minimum value in a list 📈, or converting strings to uppercase or lowercase 🔠.
#
# 😤 He was frustrated with the time and effort it was taking him to write these functions from scratch.
#
# 💡 One day, Alex's colleague suggested that he use in-built functions and methods in his programming language to simplify his code. Alex did some research and found that programming languages come with pre-defined functions and methods that can perform common tasks and operations, saving time and reducing errors.
#
# 🚀 Alex started using built-in functions like len() to calculate the length of sequences and max() and min() to find the maximum and minimum values in a list. He also began using built-in methods, such as upper() and lower() to convert strings to uppercase or lowercase.
#
# 💪 Using in-built functions and methods, Alex found that his code was more efficient and error-free. He could complete his work more quickly, and the code was easier to read and understand.
#
# 👍 From that day on, he continued to use in-built functions and methods in all his projects, and he recommended them to other developers too.

# %% [markdown]
# ##**Additional Dictionary Methods**

# %% [markdown]
# ![dict sorte.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### <code>dict()</code>
#
#
# * We can also create dictionary objects from sequence of items which are pairs. This is done using the <code>dict()</code>method
#
#
# *  <code>dict()</code> function takes the list of paired elements as argument

# %%
country_list = ['India','Australia','United States','England']
city_list = ['New Delhi', 'Canberra' , 'Washington DC','London']

# %%
country_city_list = list(zip(country_list,city_list))

# %%
country_city_list

# %%
dict(country_city_list)

# %%
# Let us create a list of paired tuples
country_city_tuples = [('India','New Delhi'),('Australia','Canberra'),('United States','Washington DC'),('England','London')]

# %%
country_city_dict = dict(country_city_tuples)

# %%
country_city_dict

# %% [markdown]
# ### We can use the <code>zip()</code> and <code>dict()</code> methods to create a dictionary object from two lists

# %%
name = ["Manjeet", "Nikhil", "Shambhavi"]
marks = [40, 50, 60]

# %%
mapped = zip(name, marks)

# %%
mapped

# %%
print(dict(mapped))

# %%
name = ["Manjeet", "Nikhil", "Shambhavi"]
marks = [40, 50, 60,80]

# %%
mapped = zip(name, marks)

# %%
print(dict(mapped))

# %% [markdown]
# ### <u>Nested Dictionaries</u>

# %% [markdown]
# ![nest dict.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# A nested dictionary is a dictionary that contains one or more other dictionaries as its values. In other words, a nested dictionary is a dictionary that has a dictionary as a value.
#
# Here's an example of a nested dictionary:
#
# ```python
# nested_dict = {'employee1': {'name': 'John', 'age': 30, 'salary': 50000},
#                'employee2': {'name': 'Jane', 'age': 25, 'salary': 45000}}
# ```
#
# In this example, the nested dictionaries **`{'name': 'John', 'age': 30, 'salary': 50000}`** and **`{'name': 'Jane', 'age': 25, 'salary': 45000}`** are the values of the outer dictionary **`nested_dict`**. The keys of the outer dictionary are 'employee1' and 'employee2.'
#
# You can access the elements of a nested dictionary by using the keys of the outer and inner dictionaries, like this:
#
# ```python
# print(nested_dict['employee1']['name']) # prints "John"
# print(nested_dict['employee2']['salary']) # prints 45000
# ```
#
# You can also add or modify elements in a nested dictionary using the keys:
#
# ```python
# nested_dict['employee1']['department'] = 'sales'
# print(nested_dict)
# ```
#
# This will add a key-value pair 'department':'sales' to the inner dictionary of employee1
#
# Nested dictionaries can be useful when you need to group multiple related pieces of data, and when the inner keys are of different types. They can also make it more difficult to access the values and make the code harder to read and understand, so it's important to use them judiciously and ensure the structure is clearly defined.
#
# You can also use dictionary comprehension to create a nested dictionary,
#
# ```python
# employee_info = {'employee' + str(i): {'name': 'John' + str(i), 'age': 30+i, 'salary':  50000+i*1000} for i in range(1,3)}
# ```
#
# This will create a dictionary with keys 'employee1,' and 'employee2', and the values are the nested dictionary with keys 'name', 'age','salary.'

# %% [markdown]
# ## **Additional Resources**

# %% [markdown]
# - [https://www.kdnuggets.com/2023/01/python-lambda-functions-explained.html](https://www.kdnuggets.com/2023/01/python-lambda-functions-explained.html)
#
# - [https://www.kaggle.com/code/ravitejayasarapu/python-built-in-functions-for-beginners](https://www.kaggle.com/code/ravitejayasarapu/python-built-in-functions-for-beginners)

# %% [markdown]
# # **Try it yourself📃📟**
#
# Are you ready to put your coding skills to the test and gain practical knowledge? We have some exciting coding questions waiting for you to solve! 🚀
#
# Your task is to attempt the coding questions associated with this lesson. These challenges have been thoughtfully designed to reinforce your understanding of the concepts covered in the course. You can find them in your dashboard under this lesson.
#
# Don't be shy! Share your findings, experiences, and any insights you gained while tackling these coding questions on the AlmaBetter community platform. Engage in discussions, help each other out, and celebrate your victories together!
#
# Remember, coding is not just about learning theory; it's about applying that knowledge to solve real-world problems. So, dive in, experiment, and have fun while honing your coding skills!
# Let's learn, grow, and inspire each other as a vibrant community of passionate learners. Happy coding! 💻 😊

# %% [markdown]
# ## **Task 1:**

# %% [markdown]
# #### **🔴Go to the AlmaBetter IDE on the Practice Tab and try solving the coding questions present there.🔴**

# %% [markdown]
# ## **Task 2:**

# %% [markdown]
# #### **🔵 Go to the AlmaBetter Community Platform and share your answers to any 3 coding questions if you have some different approach to solve the same problem.**🔵
